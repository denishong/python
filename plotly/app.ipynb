# %%
# Run this app with `python app.py` and
# visit http://127.0.0.1:8050/ in your web browser.

from dash import Dash, dcc, html
import plotly.express as px
import pandas as pd

app = Dash(__name__)

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

# %%
# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options

url = 'http://kind.krx.co.kr/corpgeneral/corpList.do?currentPageSize=5000&pageIndex=1&method=download&searchType=13'
df = pd.read_html(url,header=0)[0]
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#          회사명    종목코드               업종                    주요제품         상장일  \
# 0     AJ네트웍스   95570  산업용 기계 및 장비 임대업     렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 1    BNK금융지주  138930           기타 금융업                  금융지주회사  2011-03-30
# 2        DSR  155660      1차 비철금속 제조업                  합섬섬유로프  2013-05-15
# 3         GS   78930           기타 금융업             지주회사/부동산 임대  2004-08-05
# 4  HDC현대산업개발  294870           건물 건설업  외주주택, 자체공사, 일반건축, 토목 등  2018-06-12
#
#    결산월                     대표자명                    홈페이지     지역
# 0  12월                      손삼달  http://www.ajnet.co.kr  서울특별시
# 1  12월                      빈대인    http://www.bnkfg.com  부산광역시
# 2  12월                      홍석빈      http://www.dsr.com  부산광역시
# 3  12월       허태수, 홍순기 (각자 대표이사)                     NaN  서울특별시
# 4  12월  최익훈, 정익희, 김회언 (각자 대표이사)  http://www.hdc-dvp.com  서울특별시

# %%
df.columns
# Out:
# Index(['회사명', '종목코드', '업종', '주요제품', '상장일', '결산월', '대표자명', '홈페이지', '지역'], dtype='object')

# %%
df['지역']
# Out:
# 0       서울특별시
# 1       부산광역시
# 2       부산광역시
# 3       서울특별시
# 4       서울특별시
#         ...
# 2619      경기도
# 2620     전라북도
# 2621      경기도
# 2622     경상남도
# 2623      경기도
# Name: 지역, Length: 2624, dtype: object

# %%
fig = px.bar(df['지역'])

# %%
fig.update_layout(
    plot_bgcolor=colors['background'],
    paper_bgcolor=colors['background'],
    font_color=colors['text']
)

# %%
app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Hello Dash',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),

    html.Div(children='Dash: A web application framework for your data.', style={
        'textAlign': 'center',
        'color': colors['text']
    }),

    dcc.Graph(
        id='example-graph-2',
        figure=fig
    )
])
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: on
# /home/denishong/.local/lib/python3.10/site-packages/traitlets/traitlets.py:2548: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#   warn(
# /home/denishong/.local/lib/python3.10/site-packages/traitlets/traitlets.py:2499: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use 'c2c75f74-80aa-42cb-874d-d709fea5e0c3' instead of 'b"c2c75f74-80aa-42cb-874d-d709fea5e0c3"'.
#   warn(
# Traceback (most recent call last):
#   File "/home/denishong/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/denishong/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1042, in launch_instance
#     app.initialize(argv)
#   File "/home/denishong/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 113, in inner
#     return method(app, *args, **kwargs)
#   File "/home/denishong/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 681, in initialize
#     self.init_sockets()
#   File "/home/denishong/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 317, in init_sockets
#     self.shell_port = self._bind_socket(self.shell_socket, self.shell_port)
#   File "/home/denishong/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 252, in _bind_socket
#     return self._try_bind_socket(s, port)
#   File "/home/denishong/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 228, in _try_bind_socket
#     s.bind("tcp://%s:%i" % (self.ip, port))
#   File "/home/denishong/.local/lib/python3.10/site-packages/zmq/sugar/socket.py", line 300, in bind
#     super().bind(addr)
#   File "zmq/backend/cython/socket.pyx", line 564, in zmq.backend.cython.socket.Socket.bind
#   File "zmq/backend/cython/checkrc.pxd", line 28, in zmq.backend.cython.checkrc._check_rc
# zmq.error.ZMQError: Address already in use
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /home/denishong/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3450: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
if __name__ == '__main__':
    app.run_server(debug=True)
